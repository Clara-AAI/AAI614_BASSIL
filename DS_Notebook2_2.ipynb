# %% [markdown]
# <a href="https://colab.research.google.com/github/Clara-AAI/AAI614_BASSIL/blob/main/DS_Notebook2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 2.2: Descriptive Statistical Information*
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1_2KV4EPgDfaUl7RVcG9jDiWw_iknIVZ4?usp=sharing)
#
# [DS_Notebook2.2](https://github.com/Clara-AAI/AAI614_BASSIL/blob/main/DS_Notebook2_2.ipynb)

# %%
import pandas as pd
import ssl

ssl._create_default_https_context = ssl._create_unverified_context
alcohool = pd.read_csv("https://raw.githubusercontent.com/harmanani/AAI614/main/Week%202/niaaa-report2009.csv", index_col ='State')

# %%
alcohool.max()
# Out:
# Beer       1.72
# Wine       1.00
# Spirits    1.82
# dtype: float64

# %%
alcohool.min()
# Out:
# Beer       0.70
# Wine       0.10
# Spirits    0.45
# dtype: float64

# %%
alcohool['Beer'].median()
# Out:
# 1.22

# %%
alcohool.median()
# Out:
# Beer       1.22
# Wine       0.34
# Spirits    0.74
# dtype: float64

# %%
alcohool['Wine'].std()
# Out:
# 0.20113852411299268

# %%
alcohool.describe()
# Out:
#             Beer       Wine    Spirits
# count  51.000000  51.000000  51.000000
# mean    1.239608   0.384118   0.819804
# std     0.210200   0.201139   0.266732
# min     0.700000   0.100000   0.450000
# 25%     1.095000   0.225000   0.660000
# 50%     1.220000   0.340000   0.740000
# 75%     1.365000   0.520000   0.880000
# max     1.720000   1.000000   1.820000

# %%
alcohool.idxmax()
# Out:
# Beer              New Hampshire
# Wine       District of Columbia
# Spirits           New Hampshire
# dtype: object

# %%
alcohool.loc[:'Hawaii'].cumsum().head()
# Out:
#             Beer  Wine  Spirits
# State
# Alabama     1.20  0.22     0.58
# Alaska      2.51  0.76     1.74
# Arizona     3.70  1.14     2.48
# Arkansas    4.77  1.31     3.08
# California  5.82  1.86     3.81
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Beer'].plot(kind='hist', bins=20, title='Beer')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Wine'].plot(kind='hist', bins=20, title='Wine')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Spirits'].plot(kind='hist', bins=20, title='Spirits')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...
